# %%
# dicionario
import basedosdados as bd
import pandas as pd

a = pd.DataFrame(bd.get_table_columns(table_id='socios', dataset_id='br_me_cnpj', verbose=False))
a[['name', 'description']].to_csv()
# Out:
# ',name,description\n0,data,Data\n1,cnpj_basico,CNPJ básico\n2,tipo,Tipo\n3,nome,Nome\n4,documento,Documento (CPF mascarado ou CNPJ)\n5,qualificacao,Qualificação\n6,data_entrada_sociedade,Data de Entrada na Sociedade\n7,id_pais,ID País\n8,cpf_representante_legal,CPF do Representante Legal\n9,nome_representante_legal,Nome do Representante Legal\n10,qualificacao_representante_legal,Qualificação do Representante Legal\n11,faixa_etaria,Faixa Etária\n'

# %%
contexts = {'cnpj': """
Dados Públicos CNPJ
Quadros societários e de administradores das pessoas jurídicas brasileiras

Organização
Ministério da Economia (ME)

Cobertura temporal
2021-11 - 2022-12

,name,description\n0,data,Data\n1,cnpj_basico,CNPJ básico\n2,tipo,Tipo\n3,nome,Nome\n4,documento,Documento (CPF mascarado ou CNPJ)\n5,qualificacao,Qualificação\n6,data_entrada_sociedade,Data de Entrada na Sociedade\n7,id_pais,ID País\n8,cpf_representante_legal,CPF do Representante Legal\n9,nome_representante_legal,Nome do Representante Legal\n10,qualificacao_representante_legal,Qualificação do Representante Legal\n11,faixa_etaria,Faixa Etária\n
""",
'aluno': """
**Descrição**: Histórico e dados pessoais de todos os alunos que passaram pela rede municipal de educação.
**Frequência de atualização**: Anual
**Cobertura temporal**: Até data corrente
**Órgão gestor dos dados**: Secretaria Municipal de Educação


id_aluno	Identificador do aluno.
id_aluno_ano	
matricula	Matrícula do aluno (anonimizada).
genero	Gênero do aluno, pode ser masculino ou feminino.
naturalidade	Cidade de nascimento da criança.
nacionalidade	País de nascimento da criança.
"""}



template = """
Eu quero que você aja como um advogado especialista em proteção de dados.

Você deve responder ESTRITAMENTE o que for requerido. NÃO adicione textos desnecessários.

Você deve usar as informações contidas no dicionário de dados para responder as perguntas. 
Você pode adicionar informações do contexto que sejam relevantes. Você NÃO pode inventar informações.
Considere que os dados ainda NÃO foram abertos e você está avaliando a possibilidade de abertura desses dados.
Lembre-se que a abertura de dados é a regra e a exceção é a não abertura.

Dicionário de Dados: {context}

Baseado no dicinário de dados acima, elabore uma justificativa para a pergunta.
A justificativa não pode ser genérica e deve ser específica para os
dados em questão.

-------
Questão: {question}
Resposta em português: 
"""


question = "Qual a justificativa para que esses dados sejam abertos?"

# %%
from langchain.llms import OpenAI
from copy import deepcopy

import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
questions = [
    "1) Qual o propósito para abertura desses dados? Quais setores da sociedade serão beneficiados?",
    "2) Qual a justificativa legal para abertura? Responda com base na legislação brasileira vigente.",
    "4/5) Quais colunas que devem ser anonimizadas e quais devem ser pseudoanonimizadas? Por quê? Descreva o procedimento, passo-a-passo, aplicado nas colunas. Definição: anonimização é a remoção de dados que identifiquem uma pessoa. Pseudoanonimização é a remoção de dados que identifiquem uma pessoa, mas que permitem a reidentificação da mesma",
    "6) Quais os riscos de exposição de dados sensíveis ao cruzar esses dados com outras bases públicas? Seja específico quanto a quais bases podem ser cruzadas, quais informações podem ser descobertas e qual a probabilidade de descoberta.",
]

def apply_lgpd(contexts, questions, theme):
    res = []
    for question in questions:
        print(question)
        ans = llm(template.format(
            context=contexts[theme],
            question=question
        ))
        # print(ans)
        res.append({'question': question, 'answer': deepcopy(ans)})

    return pd.DataFrame(res)

def pprint(df):
    display(Markdown(df.to_markdown()))

aluno = apply_lgpd(contexts, questions, 'aluno')
cnpj = apply_lgpd(contexts, questions, 'cnpj')
# Out:
# 1) Qual o propósito para abertura desses dados? Quais setores da sociedade serão beneficiados?
# 2) Qual a justificativa legal para abertura? Responda com base na legislação brasileira vigente.
# 4/5) Quais colunas que devem ser anonimizadas e quais devem ser pseudoanonimizadas? Por quê? Descreva o procedimento, passo-a-passo, aplicado nas colunas. Definição: anonimização é a remoção de dados que identifiquem uma pessoa. Pseudoanonimização é a remoção de dados que identifiquem uma pessoa, mas que permitem a reidentificação da mesma
# 6) Quais os riscos de exposição de dados sensíveis ao cruzar esses dados com outras bases públicas? Seja específico quanto a quais bases podem ser cruzadas, quais informações podem ser descobertas e qual a probabilidade de descoberta.
# 1) Qual o propósito para abertura desses dados? Quais setores da sociedade serão beneficiados?
# 2) Qual a justificativa legal para abertura? Responda com base na legislação brasileira vigente.
# ...

# %%
pprint(aluno)
# Out:
# |    | question                                                                                                                                                                                                                                                                                                                                              | answer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 
# ...

# %%
pprint(cnpj)
# Out:
# |    | question                                                                                                                                                                                                                                                                                                                                              | answer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 
# ...
